# %% [markdown]
# # Derivación numérica

# %% [markdown]
# Aunque la derivada de una función se puede obtener algorítmicamente de manera analítica, los algoritmos numéricos que usemos pueden depender de muchas derivadas o no pueden acceder a otra cosa más que la función original.
#
# Así, comúnmente utilizaremos una aproximación numérica de la derivada en lugar de el valor real.

# %% [markdown]
# ## Preludio matemático: series de Taylor

# %% [markdown]
# Sea $f:\mathbb{R} \to \mathbb{R}$ diferenciable $k$ veces en un punto $a$. Entonces :
#
# $$
# f(x) = f(a) + f'(a)(x-a)+ \frac{f''(a)}{2!} (x-a)^2 + \ldots + \frac{f^{(k)}(a)}{k!}(x-a)^k + R_{k}(x)
# $$
#
# Y $R_{k}(x)$ cumple que
#
# \begin{equation}
# \lim_{x\to a} \frac{R_{k}(x)}{(x-a)^k} = 0 \quad \left( R_k(x) \sim (x-a)^{k+1}\right)
# \label{eq1}
# \end{equation}
#
# En forma aproximada, se cumple que:
# $$
# f(x) \approx f(a) + f'(a)(x-a)+ \frac{f''(a)}{2!} (x-a)^2 + \ldots + \frac{f^{(k)}(a)}{k!}(x-a)^k
# $$
#
# ### Forma explícita de $R_k(x)$
#
# Utilizando el teorema del punto medio, podemos expresar a $R_k(x)$ como
#
# $$
# R_k(x) = \frac{f^{(k+1)}(\xi)}{(k+1)!} (x-a)^{k+1}
# $$
#
# Con $\xi$ un número real **fijo** entre $x$ y $a$ **que desconocemos**. Con esta expresión, es claro que se la condición de $\lim_{x\to a} \frac{R_{k}(x)}{(x-a)^k} = 0 $ se cumple.
#
# ### Reescribir el teorema:
#
# Sustitución: $x-a = h \implies x = a+h$
#
# $$
# f(a+h) = f(a) + f'(a)(h)+ \frac{f''(a)}{2!} (h)^2 + \ldots + \frac{f^{(k)}(a)}{k!}(h)^k + R_{k}(a+h)
# $$
#
# Y $R_{k}(a+h)$ cumple que
#
# $$
# \lim_{h\to 0} \frac{R_{k}(a+h)}{h^k} = 0 \quad \left( R_k(a+h) \sim h^{k+1}\right)
# $$
#
#
#
# ## ¿Cómo aproximar la derivada?
#
# Sabemos, por definición, que la derivada de $f$ en un punto $a$ es:
#
# $$
# f'(a) = \lim_{h\to 0 } \frac{f(a+h) - f(a)}{h}
# $$
#
# **No podemos hacer limites en la computadora**. ¿Qué hacemos? Fijamos un valor de $h$ muy pequeño y aproximamos la derivada. Una aproximación de  **diferencias finitas**

# %% [markdown]
# ## Preludio computacional: funciones como objetos
#
# Aunque en clases pasadas hemos entendido a las funciones como un objeto abstracto, podemos tratarlas como un objeto con un tipo definido arbitrario. Por ahora no podemos explicar profundamente cuál es el tipo de una función, así que solo procederemos a utilizarlas como un objeto: asignar una función a una variable, dársela a otra función como argumento, etc.

# %%
# ejemplo de asignación
function f(x)
    return sin(3*x^2)
end
# Out:
# f (generic function with 1 method)

# %%
println(f(45))
# asigno a la variable `g` la función representada por `f`
g = f
# `g` me imprime el mismo valor que `f` al evaluarla
println(g(45))
# Out:
# -0.7447712875753175
# -0.7447712875753175

# %%
# ejemplo de utilizar una función como argumento de otra función
function evaluarEn3(func)
    return func(3)
end
# Out:
# evaluarEn3 (generic function with 1 method)

# %%
println(evaluarEn3(sin))
println(sin(3))
# Out:
# 0.1411200080598672
# 0.1411200080598672

# %%
println(evaluarEn3(exp))
println(exp(3))
# Out:
# 20.085536923187668
# 20.085536923187668

# %% [markdown]
# ## Derivadades de Funciones unidimensionales

# %% [markdown]
# ### Primera aproximación: diferencia hacia adelante (forward difference)
#
# Sea $h > 0$, $h << a$, utilizando una serie de Taylor, tenemos que:
#
# $$
# f(a+h) = f(a) + f'(a)h + R_{1}(a+h)
# $$
#
# Despejo la derivada:
#
# $$
# f'(a) = \frac{f(a+h)-f(a)}{h} - \frac{R_{1}(a+h)}{h}
# $$
#
# Como desconocemos el valor exacto de $R_{1}(a+h)$, podemos despreciar ese término y así aproximar:
#
# $$
# f'(a) \approx \frac{f(a+h)-f(a)}{h}
# $$
#
# Entre menor sea el valor de $h$, mejor será la aproximación ya que, por la propiedad del residuo
#
# $$
# \lim_{h \to 0} \frac{R_1(a+h)}{h} = 0
# $$

# %% [markdown]
# Notemos que el error absoluto de nuestra aproximación ($f'(a) - \frac{f(a+h) - f(a)}{h}$) está dado por el término $ \frac{R_1 (a+h)}{h}$, el cuál sabemos que es proporcional a $h$ (ya que $R_1(a+h) \sim h^2$)
#
# ## Notación:
#
# En la clase de complejidad, introducimos la notación $\mathcal{O}(f(n))$ para decir que la complejidad temporal o espacial de un algoritmo está acotada superiormente por una función de la forma $C \cdot f(n)$.
#
# En **análisis numérico**, esa misma notación se utiliza para los errores numéricos. En el caso de la diferencia hacia adelante, por la forma del error absoluto, sabemos que este es $\mathcal{O}(h)$
#
# En general, cuando el **error de aproximación** es proporcional a $h^p$, decimos que nuestro algoritmo numérico es de clase $\mathcal{O}(h^p)$. A $h^p$ también se le conoce como **orden del error**
#
# Pueden consultar más información sobre estas notaciones [en este link](https://courses.engr.illinois.edu/cs357/fa2019/references/ref-2-error/)

# %%
using Plots

# %%
function primera(x)
    return sin(2*pi*x)
end
# Out:
# primera (generic function with 1 method)

# %%
xs = range(0,stop=1,length=100)
ys = [primera(x) for x in xs]
plot(xs,ys,title="funcion a derivar")

# %% [markdown]
# Quiero implementar la aproximación
# $$
# f'(a) = \frac{f(a+h) - f(a)}{h}
# $$

# %%
# esta función me calcula la derivada de f en un punto a 
# usando la diferencia hacia adelante con un valor de h
function difAdelante(f,a,h)
    return (f(a+h) - f(a)) / h
end
# Out:
# difAdelante (generic function with 1 method)

# %% [markdown]
# Sabemos que
#
# $$
# primera'(x) = (\sin{2\pi x})' = 2 \pi \cos{2 \pi x}
# $$
#
# Podemos comparar el resultado numérico con el analítico

# %%
# derivada analítica de la funcion `primera`
function dprimera(x)
    return 2*pi*cos(2*pi*x)
end
# Out:
# dprimera (generic function with 1 method)

# %%
print("Derivada numérica: ")
println(difAdelante(primera,0,0.01))
print("Derivada analítica: ")
println(dprimera(0))
# ver el error absoluto
print("Error absoluto: ")
println(abs(dprimera(0)-difAdelante(primera,0,0.01)))
# Out:
# Derivada numérica: 6.279051952931337
# Derivada analítica: 6.283185307179586
# Error absoluto: 0.004133354248248899

# %%
# cambiando el valor de $h$ la aproximación cambia
h = 0.001
print("Derivada numérica: ")
println(difAdelante(primera,0,h))
print("Derivada analítica: ")
println(dprimera(0))
# ver el error absoluto
print("Error absoluto: ")
println(abs(dprimera(0)-difAdelante(primera,0,h)))
# Out:
# Derivada numérica: 6.283143965558951
# Derivada analítica: 6.283185307179586
# Error absoluto: 4.134162063529345e-5

# %% [markdown]
# ## La derivada aproximada como una función

# %%
# ver la derivada como función
xs = range(0,stop=1,length=101)
# grafico la derivada analítica
ys1 = [dprimera(x) for x in xs]
# tomo un $h$ fijo
h = 0.01
# hago la derivada numérica en cada punto de `xs` con ese valor de `h`
ys2 = [difAdelante(primera,x,h) for x in xs]
plot(xs,ys1,label="Valor analítico",title="Derivada")
plot!(xs,ys2,label="Diferencia hacia adelante")

# %% [markdown]
# ### Ejercicio 1
#
# Realiza una gráfica en la que compares la derivada analítica de la función $f(x) = \sin{x} \cdot \cos{x}$ con la obtenida por diferencia hacia adelante. Toma como dominio el intervalo $[-\pi,\pi]$
#
# ### Ejercicio 2
#
# Para la función del inciso anterior, fija un valor de $x$, y gráfica, el error absoluto entre la derivada analítica y la numérica como función de $h$ ¿Qué observas? ¿Es lo esperado? Utiliza la escala log-log si es necesario.

# %% [markdown]
# #### ¿Qué otras aproximaciones hay?
#
# ### Segunda aproximación: diferencia hacia atrás (backwards difference)
#
# Sea $h > 0$, $h << a$
#
# $$
# f(a-h) = f(a) + f'(a)(-h) + R_{1}(a-h)
# $$
#
# Despejo la derivada:
#
# $$
# f'(a) = \frac{f(a-h)-f(a)}{-h} - \frac{R_{1}(a-h)}{-h} = \frac{f(a)-f(a-h)}{h} + \frac{R_{1}(a-h)}{h}
# $$

# %% [markdown]
# Aproximando de la misma forma que en la diferencia hacia adelante, despreciamos el término con $R_1$ y obtenemos:
#
#
# $$
# f'(a) \approx \frac{f(a)-f(a-h)}{h}
# $$
#
# $$
# \lim_{h \to 0} \frac{R_1(a-h)}{h} = 0
# $$

# %% [markdown]
# ### Ejercicio 3
# Define una función llamada `diferenciaAtras(f,a,h)` que aproxime la derivada de $f$ en a, $f'(a)$, utilizando  una diferencia hacia atras de orden $h$

# %% [markdown]
# ### Tercera aproximación: diferencia centrada (central difference)
#
# Primero expandimos $f(a+h)$ y $f(a-h)$ en serie de taylor de orden 2:
#
# $$
# f(a+h) = f(a) + f'(a) h + \frac{f''(a)}{2!} h^2 + R_2 (a+h)
# $$
#
#
# $$
# \begin{split}
# f(a-h) &= f(a) + f'(a)(- h) + \frac{f''(a)}{2!} (-h)^2 + R_2 (a-h) \\
# &= f(a) - f'(a)h + \frac{f''(a)}{2!} h^2 + R_2 (a-h)
# \end{split}
# $$
#
# Podemos restar ambas aproximaciones:
#
# $$
# \begin{split}
# f(a+h) - f(a-h) &= (f(a) - f(a)) + (f'(a)h - (-f'(a) h)) + (\frac{f''(a)}{2!} h^2 - \frac{f''(a)}{2!} h^2) +  (R_2(a+h) - R_2(a-h)) \\
#  &=  2 f'(a) h + (R_2(a+h) - R_2(a-h))
# \end{split}
# $$
#
# Despejo la derivada:
#
# $$
# f'(a) = \frac{f(a+h) - f(a-h)}{2h} - \frac{R_2(a+h) - R_2(a-h)}{2h}
# $$
# Aproximamos igual en que en las otras aproximaciones
#
# $$
# f'(a)  \approx \frac{f(a+h) - f(a-h)}{2h}
# $$
# Mientras que el término despreciado cumple
#
# $$
# \lim_{h \to 0} \frac{R_2(a+h) - R_2(a-h)}{2h} = 0
# $$

# %% [markdown]
# ### Ejercicio 4
#
# Define una función llamada `diferenciaCentrada(f,a,h)` que aproxime la derivada de $f$ en a, $f'(a)$, utilizando  una diferencia centrada de orden $h$
#
# ### Ejercicio 5
#
# Para las siguientes funciones, realiza dos gráficas: una en la que compares las derivadas obtenidas analíticamente, con diferencia hacia adelante, diferencia hacia atrás y diferencia centrada, Y  otra gráfica en la que analices el error absoluto como función de $h$ para un punto fijo. Puedes escoger el dominio de la primera gráfica
#
# 1. $f_1(x) = 4x^3 + 10x^2 - 9$
#
# 2. $f_2(x) = e^{-x^2}\cos{(10 \pi x)}$
#
# 3. $f_3(x) = \frac{\sin{(x)}}{\sqrt[3]{x}} + \frac{x}{2}$
#
# **Sugerencia:** tus valores de $h$ no deben ser grandes, no deberían exceder $1$

# %% [markdown]
# ## Derivadas de orden superior

# %% [markdown]
# Podemos seguir el mismo esquema para obtener aproximaciones de las derivadas de orden más grande. Esto no es un proceso simple, pero para una segunda derivada podemos hacerlo de manera muy sencilla.

# %% [markdown]
# ### Ejercicio 6
#
# Suma las expansiones en serie de taylor a orden 2 de $f(a+h)$ y $f(a-h) $ para obtener una expresión para la segunda derivada $f''(a)$. ¿Cuál es su error de aproximación?
#
# ### Ejercicio 7
#
# Comprueba el error de aproximación obtenido al analizar el error absoluto en la segunda derivada de la función $\sin{(6x^2+1)}$ en un punto fijo del intervalo $[1,3]$

# %% [markdown]
# ## Funciones multidimensionales

# %% [markdown]
# Podemos también utilizar diferencias finitas para aproximar las derivadas parciales de una función $f:\mathbb{R^n} \to \mathbb{R}$. Hacer expresiones de las derivadas de orden superior se vuelve complicado ya que hay que hacer expansiones de Taylor multidimensionales, pero para las primeras derivadas parciales basta recordar la definición
#
# $$
# \frac{\partial f}{\partial x_k} (a_1, \ldots, a_n) = \lim_{h \to 0} \frac{f(a_1, \ldots, a_k + h, \ldots, a_n) - f(a_1, \ldots, a_k, \ldots, a_n)}{h}
# $$
#
# ### Ejercicio 8
#
# Define una función `devParcial(f,i,A,h)`, donde $f:\mathbb{R^n} \to \mathbb{R}$ es una función multivariada, que toma como argumento un solo arreglo, $A$ es un arreglo de longitud $n$ e $1\leq i \leq n$ es un natural, que te regrese la derivdad parcial $\frac{\partial f}{\partial x_i} (A)$ calculada utilizando una diferencia central de orden $h$. Pruebala con alguna función de tu elección.
#
# ### Ejercicio 9
#
# Sea $g:\mathbb{R}^2 \to \mathbb{R}$, obtén una expresión **analítica** (i.e. no deben programar nada) de diferencias finitas para la derivada curzada $\frac{\partial^2 g}{\partial x \partial y}$. ¿Cuál es el orden de su error de aproximación?
#
# **Sugerencia:** Hay dos maneras de obtener la expresión, y para ambas debes suponer que las parciales cruzadas son iguales $\frac{\partial^2 f}{\partial x\partial y} = \frac{\partial^2 f}{\partial y \partial x}$. La manera larga es usar una serie de Taylor Multidimensional y resolver el sistema de ecuaciones que se obtiene. La manera corta es realizar dos aproximaciones simultáneas en cada entrada.

# %% [markdown]
# ## La visión general:
#
# Las diferencias hacia adelante, hacia atrás y centrada, son aproximaciones malas y un tanto pobres que no se utilizan con extrema frecuencia en la vida real.
#
# Existe una manera de derivar aproximaciones de diferencias finitas arbitrarias que sean $\mathcal{O}(h^p)$ para el $p \in \mathbb{N}$ que yo quiera. Ese método escapa al alcance del curso, pero lo pueden consultar en el libro de LeVeque de la bibliografía.
#
# Existe también una manera de calcular las derivadas de manera exacta, llamada **diferenciación automática**. No veremos ese tema pues requiere de conocimientos más avanzados de programación.
